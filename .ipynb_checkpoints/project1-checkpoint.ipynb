# %%
# # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys
# Import API key
from api_keys import api_key
#Read csv data set
tmdb_5000_movies = "Resources/tmdb_5000_movies.csv"
release_dates_per_country="Resources/release_dates_per_country.csv"
tmdb_data=pd.read_csv(tmdb_5000_movies)
release_data=pd.read_csv(release_dates_per_country)
#output data path
output_data_file = "output_data/tmd_api_movie.csv"

# %%
#Generate movie id list
movie_5000_id = tmdb_data["id"].tolist()
movie_release_id =release_data["movie_id"].tolist()
#Combine movie id list by unique values
movie_id=np.unique(movie_5000_id+movie_release_id)
print(len(movie_id))
#check the id to see if there is some value other than integer
print(movie_id)
# Out:
# 8798
# [     0      5      6 ... 559250 573531 575273]

# %%
# #test cell
# base_url = "https://api.themoviedb.org/3/discover/movie/"
# url=base_url+"?api_key="+api_key+"&language=en-US"+"&primary_release_date.gte=2019-01-01&primary_release_date.lte=2019-01-01"
# response=requests.get(url).json()
# m_list=[]
# print(response["total_results"])

# %%
#test api key to see the api structure in chrome
base_url = "https://api.themoviedb.org/3/movie/"
url=base_url+str(290)+"?api_key="+api_key+"&language=en-US"
response=requests.get(url).json()
print(url)

# %%
#initial counter
record_counter=0
set_counter=1

#define list
id_list=[]
title_list=[]
adult_list=[]
budget_list=[]
genres_list=[]
language_list=[]
pop_list=[]
company_list=[]
country_list=[]
release_date_list=[]
revenue_list=[]
run_time_list=[]
vote_ave_list=[]
vote_count_list=[]

base_url = "https://api.themoviedb.org/3/movie/"

print("Beginning Data Retrieval\n")
print("-"*30)
#Scrap data from api
for m_id in movie_id:
    try:
        url=base_url+str(m_id)+"?api_key="+api_key#+"&language=en-US"
        response=requests.get(url).json()
        id_list.append(response["id"])
        title_list.append(response["title"])
        adult_list.append(response["adult"])
        budget_list.append(response["budget"])
        genres_list.append([i["name"] for i in response["genres"]])
        language_list.append(response["original_language"])
        pop_list.append(response["popularity"])
        company_list.append([j["name"] for j in response["production_companies"]])
        country_list.append([k["name"] for k in response["production_countries"]])
        release_date_list.append(response["release_date"])
        revenue_list.append(response["revenue"])
        run_time_list.append(response["runtime"])
        vote_ave_list.append(response["vote_average"])
        vote_count_list.append(response["vote_count"])
        
        record_counter+=1
        sys.stdout.write('\r'+'Processing Record '+str(record_counter))
        sys.stdout.flush()
        if record_counter==1000:  # test loop use only
            break
#        if record_counter==51:
#             record_counter=1
#             set_counter+=1
#        print("Processing Record "+str(record_counter)+" | Movie ID"+ str(m_id))

    except:
        pass

#        print("Movie not found. Skipping ...")
#print ("-"*30)
print ("\nData Retrieval Complete\n")
print ("-"*30)
print ("Movie Found "+str(record_counter))
# Out:
# Beginning Data Retrieval
#
# ------------------------------
# Processing Record 1000
# Data Retrieval Complete
#
# ------------------------------
# Movie Found 1000

# %%
movie_df=pd.DataFrame({"ID":id_list,
                       "Title": title_list,
                         "Adult":adult_list,
                        "Budget":budget_list,
                           "Genres":genres_list,
                         "Language":language_list,
                          "Production Company":company_list,
                         "Popularity":pop_list,
                          "Revenue":revenue_list,
                            "Production Country":country_list,
                          "Release Date":release_date_list,
                          "Run Time":run_time_list,
                          "Vote Average":vote_ave_list,
                        "Vote Count":vote_count_list})
movie_df
# Out:
#        ID                                              Title  Adult  \
# 0       5                                         Four Rooms  False
# 1       6                                     Judgment Night  False
# 2      11                                          Star Wars  False
# 3      12                                       Finding Nemo  False
# 4      13                                       Forrest Gump  False
# 5      14                                    American Beauty  False
# 6      15                                       Citizen Kane  False
# 7      16                                 Dancer in the Dark  False
# 8      18                                  The Fifth Element  False
# 9      19                                         Metropolis  False
# 10     20                                 My Life Without Me  False
# 11     22  Pirates of the Caribbean: The Curse of the Bla...  False
# 12     24                                  Kill Bill: Vol. 1  False
# 13     25                                            Jarhead  False
# 14     27                                            9 Songs  False
# 15     28                                     Apocalypse Now  False
# 16     33                                         Unforgiven  False
# 17     35                                 The Simpsons Movie  False
# 18     38              Eternal Sunshine of the Spotless Mind  False
# 19     55                                      Amores Perros  False
# 20     58         Pirates of the Caribbean: Dead Man's Chest  False
# 21     59                              A History of Violence  False
# 22     62                              2001: A Space Odyssey  False
# 23     63                                     Twelve Monkeys  False
# 24     64                                        Talk to Her  False
# 25     65                                             8 Mile  False
# 26     66                                     Absolute Power  False
# 27     67                                       Paradise Now  False
# 28     68                                             Brazil  False
# 29     69                                      Walk the Line  False
# ..    ...                                                ...    ...
# 970  2210                               Earth Girls Are Easy  False
# 971  2211                                     Aimee & Jaguar  False
# 972  2212                                         Nightwatch  False
# 973  2239                                         Hallam Foe  False
# 974  2246                                             Malice  False
# 975  2251                                         Unfaithful  False
# 976  2252                                   Eastern Promises  False
# 977  2253                                           Valkyrie  False
# 978  2255                                        Chasing Amy  False
# 979  2260                            Capturing the Friedmans  False
# 980  2263                                          Music Box  False
# 981  2266                                   Paris, Je T'Aime  False
# 982  2267                                     The Last Mimzy  False
# 983  2268                                 The Golden Compass  False
# 984  2269                                          Day Watch  False
# 985  2270                                           Stardust  False
# 986  2275                             The General's Daughter  False
# 987  2277                                   Bicentennial Man  False
# 988  2280                                                Big  False
# 989  2284                     Mr. Magorium's Wonder Emporium  False
# 990  2287                                               Rize  False
# 991  2288                                             Closer  False
# 992  2289                                      Cold Mountain  False
# 993  2290                                     Jakob the Liar  False
# 994  2291                                     Jacob's Ladder  False
# 995  2292                                             Clerks  False
# 996  2293                                           Mallrats  False
# 997  2294                     Jay and Silent Bob Strike Back  False
# 998  2295                                          Clerks II  False
# 999  2300                                          Space Jam  False
#
#         Budget                                             Genres Language  \
# 0      4000000                                    [Crime, Comedy]       en
# 1     21000000                          [Action, Thriller, Crime]       en
# 2     11000000               [Adventure, Action, Science Fiction]       en
# 3     94000000                                [Animation, Family]       en
# 4     55000000                           [Comedy, Drama, Romance]       en
# 5     15000000                                            [Drama]       en
# 6       839727                                   [Mystery, Drama]       en
# 7     12800000                              [Drama, Crime, Music]       en
# 8     90000000  [Adventure, Fantasy, Action, Thriller, Science...       en
# 9     92620000                           [Drama, Science Fiction]       de
# 10           0                                   [Drama, Romance]       en
# 11   140000000                       [Adventure, Fantasy, Action]       en
# 12    30000000                                    [Action, Crime]       en
# 13    72000000                                       [Drama, War]       en
# 14     1000000                            [Drama, Music, Romance]       en
# 15    31500000                                       [Drama, War]       en
# 16    14000000                                          [Western]       en
# 17    75000000                        [Animation, Comedy, Family]       en
# 18    20000000                  [Science Fiction, Drama, Romance]       en
# 19     2000000                                  [Drama, Thriller]       es
# 20   200000000                       [Adventure, Fantasy, Action]       en
# 21    32000000                           [Drama, Thriller, Crime]       en
# 22    12000000              [Science Fiction, Mystery, Adventure]       en
# 23    29500000               [Science Fiction, Thriller, Mystery]       en
# 24           0                                   [Drama, Romance]       es
# 25    41000000                                     [Drama, Music]       en
# 26    50000000                                            [Crime]       en
# 27           0                           [Thriller, Crime, Drama]       en
# 28    15000000                          [Comedy, Science Fiction]       en
# 29    28000000                            [Drama, Music, Romance]       en
# ..         ...                                                ...      ...
# 970   10000000                   [Music, Comedy, Science Fiction]       en
# 971          0                          [Drama, History, Romance]       de
# 972          0         [Action, Drama, Horror, Mystery, Thriller]       en
# 973    8000000                          [Drama, Comedy, Thriller]       en
# 974          0                                         [Thriller]       en
# 975   50000000                                         [Thriller]       en
# 976   51500000                         [Thriller, Crime, Mystery]       en
# 977   75000000                    [Drama, Thriller, History, War]       en
# 978     250000                           [Comedy, Drama, Romance]       en
# 979          0                                      [Documentary]       en
# 980          0                                         [Thriller]       en
# 981   13000000                                   [Drama, Romance]       fr
# 982          0        [Family, Drama, Science Fiction, Adventure]       en
# 983  180000000                               [Adventure, Fantasy]       en
# 984    4200000                         [Fantasy, Science Fiction]       ru
# 985   70000000              [Adventure, Fantasy, Romance, Family]       en
# 986   60000000                  [Crime, Drama, Mystery, Thriller]       en
# 987  100000000                   [Comedy, Science Fiction, Drama]       en
# 988   18000000          [Fantasy, Drama, Comedy, Romance, Family]       en
# 989          0                          [Comedy, Family, Fantasy]       en
# 990          0                                      [Documentary]       en
# 991   27000000                                   [Drama, Romance]       en
# 992   79000000               [Adventure, Drama, History, Romance]       en
# 993   45000000                           [Comedy, Drama, History]       en
# 994   25000000                           [Drama, Mystery, Horror]       en
# 995      27000                                           [Comedy]       en
# 996    6000000                                  [Romance, Comedy]       en
# 997   22000000                                           [Comedy]       en
# 998    5000000                                           [Comedy]       en
# 999   80000000                        [Animation, Comedy, Family]       en
#
#                                     Production Company  Popularity  \
# 0                              [Miramax, A Band Apart]      21.209
# 1    [Universal Pictures, Largo Entertainment, JVC ...       8.069
# 2                        [Lucasfilm, 20th Century Fox]      51.111
# 3                                              [Pixar]      45.733
# 4                                          [Paramount]      31.971
# 5           [Jinks/Cohen Company, DreamWorks Pictures]      30.525
# 6            [RKO Radio Pictures, Mercury Productions]      20.712
# 7    [Lantia Cinema & Audiovisivi, Fine Line Featur...      14.581
# 8                         [Columbia Pictures, Gaumont]      40.552
# 9                               [Universum Film (UFA)]      14.529
# 10                   [El Deseo, Milestone Productions]      21.969
# 11     [Jerry Bruckheimer Films, Walt Disney Pictures]      52.215
# 12          [Miramax, A Band Apart, Super Cool ManChu]      35.499
# 13   [Universal Pictures, Red Wagon Entertainment, ...      21.950
# 14                                  [Revolution Films]      16.116
# 15                  [United Artists, Zoetrope Studios]      27.925
# 16        [Malpaso Productions, Warner Bros. Pictures]      20.039
# 17   [AKOM Production Company, Gracie Films, Rough ...      19.390
# 18   [Focus Features, Anonymous Content, This Is Th...      22.281
# 19                   [Altavista Films, Zeta Film (MX)]      15.069
# 20   [Walt Disney Pictures, Jerry Bruckheimer Films...      32.818
# 21           [New Line Cinema, BenderSpink, DC Comics]      16.980
# 22   [Stanley Kubrick Productions, Metro-Goldwyn-Ma...      31.215
# 23   [Universal Pictures, Atlas Entertainment, Clas...      27.357
# 24   [Vía Digital, Good Machine, Antena 3 Televisió...       9.869
# 25   [Mikona Productions GmbH & Co. KG, Imagine Ent...      15.611
# 26   [Columbia Pictures, Castle Rock Entertainment,...      11.407
# 27   [Eurimages, Lama Films, Augustus Film, Lama Pr...       9.387
# 28                    [Embassy International Pictures]      17.295
# 29   [Mars Media Beteiligungs, Tree Line Films, Kon...      20.192
# ..                                                 ...         ...
# 970  [Earth Girls, De Laurentiis Entertainment Grou...       9.974
# 971                          [Senator Film Produktion]       2.597
# 972        [Dimension Films, Michael Obel Productions]       8.116
# 973                                                 []       5.825
# 974  [Nelvana Limited, Columbia Pictures, Castle Ro...      15.459
# 975  [Unfaithful Filmproduktion GmbH & Co. KG, Fox ...      18.617
# 976  [Focus Features, BBC Films, Astral Media, Coru...      26.981
# 977  [United Artists, Bad Hat Harry Productions, Ac...      15.309
# 978                  [View Askew Productions, Miramax]      14.792
# 979        [HBO Documentary Films, Notorious Pictures]       8.431
# 980               [TriStar Pictures, Carolco Pictures]       4.996
# 981  [Filmazure, Pirol Stiftung, Victoires Internat...      10.063
# 982                     [Michael Phillips Productions]       8.921
# 983  [Depth of Field, New Line Cinema, Scholastic P...      21.103
# 984         [Bazelevs Production, TABBAK, Channel One]      10.370
# 985  [Paramount, Marv Films, Vaughn Productions, Di...      19.951
# 986  [MFP Munich Film Partners GmbH & Company I. Pr...      13.469
# 987  [1492 Pictures, Laurence Mark Productions, Rad...      12.752
# 988  [American Entertainment Partners II L.P., Grac...      13.262
# 989  [Ontario Media Development Corporation (OMDC),...      11.301
# 990  [David LaChapelle Studios, HSI Productions, Da...       4.451
# 991                                [Columbia Pictures]      18.919
# 992  [Miramax, Mirage Enterprises, Bona Fide Produc...      15.551
# 993  [Global Entertainment Productions GmbH & Compa...       8.470
# 994               [TriStar Pictures, Carolco Pictures]      14.496
# 995                  [View Askew Productions, Miramax]      20.005
# 996  [Universal Pictures, Gramercy Pictures, Alphav...      17.327
# 997  [Dimension Films, View Askew Productions, Mira...      23.407
# 998    [View Askew Productions, The Weinstein Company]      10.790
# 999  [Courtside Seats Productions, Warner Bros. Fam...      18.281
#
#         Revenue                                 Production Country  \
# 0       4300000                         [United States of America]
# 1      12136938                  [Japan, United States of America]
# 2     775398007                         [United States of America]
# 3     940335536                         [United States of America]
# 4     677945399                         [United States of America]
# 5     356296601                         [United States of America]
# 6      23217674                         [United States of America]
# 7      40031879  [Argentina, Denmark, Finland, France, Germany,...
# 8     263920180                                           [France]
# 9        650422                                          [Germany]
# 10      9726954                                    [Canada, Spain]
# 11    655011224                         [United States of America]
# 12    180949045                         [United States of America]
# 13     96889998                [Germany, United States of America]
# 14      1574623                                   [United Kingdom]
# 15     89460381                         [United States of America]
# 16    159157447                         [United States of America]
# 17    527068851                         [United States of America]
# 18     72258126                         [United States of America]
# 19     20908467                                           [Mexico]
# 20   1065659812                         [United States of America]
# 21     60740827        [United States of America, Canada, Germany]
# 22     68700000         [United Kingdom, United States of America]
# 23    168840000                         [United States of America]
# 24     51001550                                            [Spain]
# 25    242875078                         [United States of America]
# 26     50068310                         [United States of America]
# 27      3357075  [Palestinian Territory, France, Germany, Israe...
# 28            0                                   [United Kingdom]
# 29    186438883                [Germany, United States of America]
# ..          ...                                                ...
# 970     3916303         [United Kingdom, United States of America]
# 971           0                                          [Germany]
# 972     1179002                         [United States of America]
# 973       60641                                   [United Kingdom]
# 974    46405336                         [United States of America]
# 975   119137784                         [United States of America]
# 976    56106607  [United Kingdom, United States of America, Can...
# 977   200276000                [Germany, United States of America]
# 978    12021272                         [United States of America]
# 979     3117985                         [United States of America]
# 980     6263883                         [United States of America]
# 981     4857367                                           [France]
# 982    27297450                         [United States of America]
# 983   372234864         [United Kingdom, United States of America]
# 984    38862717                                           [Russia]
# 985   135560026  [Iceland, United Kingdom, United States of Ame...
# 986   149705852                [Germany, United States of America]
# 987           0                 [Canada, United States of America]
# 988   151668774                         [United States of America]
# 989    69474661                 [Canada, United States of America]
# 990           0                         [United States of America]
# 991   115505027                         [United States of America]
# 992   173013509  [United States of America, United Kingdom, Rom...
# 993     4956701        [France, Hungary, United States of America]
# 994    25965144                         [United States of America]
# 995     3151130                         [United States of America]
# 996     2122561                         [United States of America]
# 997    33788161                         [United States of America]
# 998    26888376                         [United States of America]
# 999   250200000                         [United States of America]
#
#     Release Date  Run Time  Vote Average  Vote Count
# 0     1995-12-09        98           6.1        1311
# 1     1993-10-15       110           6.6         127
# 2     1977-05-25       121           8.2       12116
# 3     2003-05-30       100           7.8       12359
# 4     1994-07-06       142           8.4       15946
# 5     1999-09-15       122           8.0        6959
# 6     1941-04-30       119           8.1        2610
# 7     2000-05-17       141           7.9         859
# 8     1997-05-02       126           7.4        6596
# 9     1927-01-10       153           8.2        1259
# 10    2003-03-07       106           6.2         205
# 11    2003-07-09       143           7.7       13078
# 12    2003-10-10       111           7.9       10209
# 13    2005-11-04       123           6.5        1351
# 14    2004-07-16        66           5.0         184
# 15    1979-08-15       153           8.2        4251
# 16    1992-08-07       131           7.9        2069
# 17    2007-07-26        87           6.9        4845
# 18    2004-03-19       108           8.1        8046
# 19    2000-06-16       154           7.6        1103
# 20    2006-06-20       151           7.2        9933
# 21    2005-09-23        96           7.1        1609
# 22    1968-04-09       149           8.0        6286
# 23    1995-12-29       129           7.6        4577
# 24    2002-03-14       112           7.6         552
# 25    2002-11-08       110           7.0        3676
# 26    1997-02-14       121           6.6         442
# 27    2005-02-14        90           6.9         116
# 28    1985-02-20       132           7.7        1720
# 29    2005-09-13       136           7.5        1435
# ..           ...       ...           ...         ...
# 970   1988-05-12       100           5.5         178
# 971   1999-02-10       125           7.0          44
# 972   1997-01-31       102           6.0         197
# 973   2007-02-16        95           6.8          72
# 974   1993-09-29       107           6.1         196
# 975   2002-05-10       124           6.4         594
# 976   2007-09-14       100           7.3        1670
# 977   2008-12-25       121           6.8        2058
# 978   1997-04-04       114           6.8         748
# 979   2003-05-30       107           7.4         177
# 980   1989-12-22       124           7.1          50
# 981   2006-05-16       120           6.8         396
# 982   2007-02-09        94           6.1         233
# 983   2007-12-04       113           6.0        2820
# 984   2006-01-01       132           6.1         278
# 985   2007-08-09       127           7.2        2304
# 986   1999-06-18       116           6.3         410
# 987   1999-12-17       131           7.2        2059
# 988   1988-06-03       104           7.0        1946
# 989   2007-11-14        93           6.2         719
# 990   2005-01-15        86           6.5          17
# 991   2004-12-01       104           6.8        1783
# 992   2003-12-24       154           6.9         970
# 993   1999-09-16       120           6.4         168
# 994   1990-11-02       113           7.4         730
# 995   1994-09-13        92           7.4        1356
# 996   1995-10-20        94           6.8         644
# 997   2001-08-22       104           6.3         828
# 998   2006-07-21        97           6.9         695
# 999   1996-11-15        88           6.7        3029
#
# [1000 rows x 14 columns]

# %%
#save data frame to csv
movie_df.to_csv("output_data/tmd_api_movie_original.csv",index=False)

# %%
# genre_df=pd.DataFrame(movie_df["Genres"].values.tolist(), columns = ["Genre1", "Genre2", "Genre3",
#                                                                     "Genre4","Genre5","Genre6","Genre7","Genre8"])
# company_df=pd.DataFrame(movie_df["Production Company"].values.tolist(),columns = ["company1","company2","company3","company4","company5","company6","company7","company8","company9","company10","company11","company12","company13",
#                                                                                   "company14","company15","company16","company17","company18","company19","company20","company21","company22","company23","company24","company25","company26"])
# #country_df=pd.DataFrame(movie_df["Production Country"].values.tolist(),columns=["Country1","Country2","Country3"])

# %%
# movie_final_df = pd.concat([movie_df,genre_df,company_df],axis=1)
# movie_final_df = movie_final_df.drop(["Genres","Production Company"], axis = 1)
# movie_final_df.head()

# %%
# #save data frame to csv
# movie_final_df.to_csv("output_data/tmd_api_movie.csv",index=False)
