# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### Initial Dependencies

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# ignore some warnings if dataframe is changing
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Preview DataFrame

# %%
df = pd.read_csv("output_data/cleanup_movie_2019.csv")
df.head()
# Out:
#        ID                         Title  Adult       Budget  \
# 0  475557                         Joker  False   55000000.0
# 1  420809  Maleficent: Mistress of Evil  False          NaN
# 2  420818                 The Lion King  False  260000000.0
# 3  290859         Terminator: Dark Fate  False  160000000.0
# 4  429617     Spider-Man: Far from Home  False  160000000.0
#
#                                        Genres  \
# 0              ['Crime', 'Thriller', 'Drama']
# 1          ['Fantasy', 'Adventure', 'Family']
# 2         ['Adventure', 'Animation', 'Drama']
# 3               ['Action', 'Science Fiction']
# 4  ['Action', 'Adventure', 'Science Fiction']
#
#                                   Production Company  Popularity  \
# 0  ['DC Entertainment', 'Warner Bros. Pictures', ...     462.910
# 1                           ['Walt Disney Pictures']     287.919
# 2  ['Walt Disney Pictures', 'Fairview Entertainme...     183.255
# 3  ['Lightstorm Entertainment', 'Skydance Media',...     153.313
# 4  ['Marvel Studios', 'Sony Pictures', 'Columbia ...     123.576
#
#         Revenue                     Production Country  Run Time  \
# 0  5.685095e+08           ['United States of America']     122.0
# 1           NaN           ['United States of America']     118.0
# 2  1.649677e+09           ['United States of America']     118.0
# 3           NaN  ['China', 'United States of America']     128.0
# 4  1.131450e+09           ['United States of America']     129.0
#
#    Vote Average  Vote Count omdb_rated    omdb_director  \
# 0           8.6        3863          R    Todd Phillips
# 1           7.1         317         PG  Joachim Rønning
# 2           7.1        3132         PG      Jon Favreau
# 3           7.4          29        NaN       Tim Miller
# 4           7.6        4610      PG-13        Jon Watts
#
#                                          omdb_actors            omdb_language  \
# 0  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...                  English
# 1  Angelina Jolie, Elle Fanning, Imelda Staunton,...                  English
# 2  Chiwetel Ejiofor, John Oliver, James Earl Jone...                  English
# 3  Linda Hamilton, Arnold Schwarzenegger, Mackenz...                  English
# 4  Tom Holland, Samuel L. Jackson, Jake Gyllenhaa...  Italian, Czech, English
#
#    omdb_metascore  omdb_imdbRating omdb_imdbVotes
# 0            59.0              8.9        360,218
# 1             NaN              NaN            NaN
# 2            55.0              7.1        102,621
# 3             NaN              NaN            NaN
# 4            69.0              7.7        187,214

# %%
#Drop the null values in the subset
set1=["Title","Popularity","Run Time","Vote Average","omdb_imdbRating","omdb_metascore"]
#Check data 
df_runtime=df[set1].dropna().reset_index(drop=True)
df_runtime.head()
# Out:
#                              Title  Popularity  Run Time  Vote Average  \
# 0                            Joker     462.910     122.0           8.6
# 1                    The Lion King     183.255     118.0           7.1
# 2        Spider-Man: Far from Home     123.576     129.0           7.6
# 3  El Camino: A Breaking Bad Movie     109.708     123.0           7.2
# 4                      Toy Story 4      94.602     100.0           7.6
#
#    omdb_imdbRating  omdb_metascore
# 0              8.9            59.0
# 1              7.1            55.0
# 2              7.7            69.0
# 3              7.7            72.0
# 4              8.1            84.0

# %%
#Remove the outlier
df_runtime=df_runtime.loc[df_runtime['Popularity']!=df_runtime['Popularity'].max()]

# %%
#set axis and tick locations
x_axis=df_runtime["Run Time"]
plt.figure(figsize=(12,8))
plt.scatter(x_axis,df_runtime["Popularity"], facecolor = "darkviolet", edgecolor = "grey", alpha = 0.2)
# Set a Title and labels
plt.title("Popularity vs. Run Time")
plt.xlabel("Run Time")
plt.ylabel("Popularity")
#plt.tight_layout()
plt.savefig("output_data/POPvsRT.png")
plt.show()

# %%
#set axis and tick locations
x_axis=df_runtime["Run Time"]
plt.figure(figsize=(12,8))
plt.scatter(x_axis,df_runtime["omdb_imdbRating"], facecolor = "deeppink", edgecolor = "grey", alpha = 0.2)
# Set a Title and labels
plt.title("omdb_imdbRating vs. Run Time")
plt.xlabel("Run Time")
plt.ylabel("omdb_imdbRating")
#plt.tight_layout()
plt.savefig("output_data/RatingvsRT.png")
plt.show()

# %%
#Drop the null values in the subset
set2=["Title","Genres","omdb_director","omdb_actors","Vote Average","Popularity"]
df_set2=df[set2].dropna().reset_index(drop=True)
df_set2.head()
# Out:
#                           Title                                      Genres  \
# 0                         Joker              ['Crime', 'Thriller', 'Drama']
# 1  Maleficent: Mistress of Evil          ['Fantasy', 'Adventure', 'Family']
# 2                 The Lion King         ['Adventure', 'Animation', 'Drama']
# 3         Terminator: Dark Fate               ['Action', 'Science Fiction']
# 4     Spider-Man: Far from Home  ['Action', 'Adventure', 'Science Fiction']
#
#      omdb_director                                        omdb_actors  \
# 0    Todd Phillips  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...
# 1  Joachim Rønning  Angelina Jolie, Elle Fanning, Imelda Staunton,...
# 2      Jon Favreau  Chiwetel Ejiofor, John Oliver, James Earl Jone...
# 3       Tim Miller  Linda Hamilton, Arnold Schwarzenegger, Mackenz...
# 4        Jon Watts  Tom Holland, Samuel L. Jackson, Jake Gyllenhaa...
#
#    Vote Average  Popularity
# 0           8.6     462.910
# 1           7.1     287.919
# 2           7.1     183.255
# 3           7.4     153.313
# 4           7.6     123.576

# %%
#split Genres Columns
genre=df.Genres.str.split(",")
# df_genre=pd.DataFrame(df_set2.Genres.values.tolist())
# df_genre.head(1)
genre
# Out:
# 0                      [['Crime',  'Thriller',  'Drama']]
# 1                  [['Fantasy',  'Adventure',  'Family']]
# 2                 [['Adventure',  'Animation',  'Drama']]
# 3                        [['Action',  'Science Fiction']]
# 4          [['Action',  'Adventure',  'Science Fiction']]
# 5                      [['Crime',  'Drama',  'Thriller']]
# 6       [['Adventure',  'Animation',  'Comedy',  'Fami...
# 7                      [['Horror',  'Action',  'Comedy']]
# 8                      [['Action',  'Drama',  'History']]
# 9                               [['Action',  'Thriller']]
# 10                                           [['Action']]
# 11                              [['Action',  'Thriller']]
# 12                                           [['Horror']]
# 13                                           [['Horror']]
# 14      [['Adventure',  'Fantasy',  'Romance',  'Comed...
# 15               [['Animation',  'Action',  'Adventure']]
# 16                    [['Action',  'Thriller',  'Crime']]
# 17      [['Fantasy',  'Adventure',  'Action',  'Family...
# 18         [['Science Fiction',  'Action',  'Adventure']]
# 19         [['Adventure',  'Action',  'Science Fiction']]
# 20      [['Action',  'Adventure',  'Comedy',  'Fantasy']]
# 21                                         [['Thriller']]
# 22                                 [['Drama',  'Comedy']]
# 23                       [['Drama',  'Crime',  'Comedy']]
# 24                       [['Comedy',  'Crime',  'Drama']]
# 25      [['Action',  'Adventure',  'Animation',  'Scie...
# 26                       [['Comedy',  'Crime',  'Drama']]
# 27      [['Animation',  'Comedy',  'Family',  'Horror'...
# 28                            [['Adventure',  'Fantasy']]
# 29      [['Action',  'Mystery',  'Science Fiction',  '...
#                               ...
# 9964                             [['Thriller',  'Drama']]
# 9965              [['Thriller',  'Adventure',  'Action']]
# 9966                             [['Thriller',  'Crime']]
# 9967       [['TV Movie',  'Mystery',  'Crime',  'Drama']]
# 9968                            [['Action',  'Thriller']]
# 9969                [['Action',  'Animation',  'Comedy']]
# 9970                                    [['Documentary']]
# 9971                                        [['Fantasy']]
# 9972                   [['Drama',  'Family',  'Romance']]
# 9973                                         [['Comedy']]
# 9974                                    [['Documentary']]
# 9975    [['Adventure',  'Animation',  'Comedy',  'Fami...
# 9976        [['Horror',  'Thriller',  'Drama',  'Crime']]
# 9977                               [['Comedy',  'Drama']]
# 9978                                          [['Drama']]
# 9979                                          [['Drama']]
# 9980                             [['Fantasy',  'Horror']]
# 9981       [['Mystery',  'Science Fiction',  'Thriller']]
# 9982                                         [['Horror']]
# 9983                                         [['Comedy']]
# 9984                                       [['Thriller']]
# 9985                                                 [[]]
# 9986                               [['Drama',  'Family']]
# 9987                                         [['Comedy']]
# 9988          [['Science Fiction',  'Comedy',  'Horror']]
# 9989                 [['Action',  'Horror',  'Thriller']]
# 9990                                         [['Comedy']]
# 9991                 [['Horror',  'Fantasy',  'Mystery']]
# 9992                              [['Drama',  'Romance']]
# 9993                                         [['Horror']]
# Name: Genres, Length: 9994, dtype: object

# %%
#split actor columns 
actor=df.omdb_actors.str.split(",")
df_actor=pd.DataFrame(actor.values.tolist())
df_actor.head(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6d96f1bc3430> in <module>
#       1 #split actor columns
#       2 actor=df.omdb_actors.str.split(",")
# ----> 3 df_actor=pd.DataFrame(actor.values.tolist())
#       4 df_actor.head(1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     432     else:
#     433         # list of lists
# --> 434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
#     436                                  coerce_float=coerce_float)
#
# pandas/_libs/lib.pyx in pandas._libs.lib.to_object_array()
#
# TypeError: object of type 'float' has no len()

# %%
#add columns name to actors
df_actor.columns=["Actor 1","Actor 2","Actor 3","Actor 4"]
df_actor.head(1)

# %%
df_actor_a=df[["Title", "Budget","Popularity","Revenue","omdb_director"]]
df_actor_analysis=pd.concat([df_actor_a,df_actor],axis=1)
df_actor_r1=df_actor_analysis.groupby("Actor 1").Revenue.sum().reset_index(name="Revenue 1").set_index('Actor 1')
df_actor_r2=df_actor_analysis.groupby("Actor 2").Revenue.sum().reset_index(name="Revenue 2").set_index('Actor 2')
df_actor_r3=df_actor_analysis.groupby("Actor 3").Revenue.sum().reset_index(name="Revenue 3").set_index('Actor 3')
df_actor_r4=df_actor_analysis.groupby("Actor 4").Revenue.sum().reset_index(name="Revenue 4").set_index('Actor 4')
df_actor_rtotal=pd.concat([df_actor_r1,df_actor_r2,df_actor_r3,df_actor_r4],axis=1)
df_actor_rtotal=df_actor_rtotal.sum(axis=1).reset_index(name="Total Revenue").set_index('index').sort_values(by="Total Revenue",ascending=False)
df_actor_rtotal.index.name=None
df_actor_rtotal.head()
