# %% [markdown]
# ## General Clean Up Data and Save to CSV file
# ##### Drop columns with the same data info and convert the 0 values in Budget and Revenue Section to Null, in order to finalize the final Data frame for analyzing

# %%
# # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys
# Import API key
# from api_keys import api_key
# from api_keys2 import api_key2

# %% [markdown]
# #### Merge OMDB & TMDB From Excel files

# %%
# Recall the OMDB data and TMDB data
df_tmdb = pd.read_csv("output_data/tmd_api_movie_2019.csv")
df_omdb = pd.read_csv("output_data/omdb_api_movie_2019.csv")

# %%
#combine the OMDB and TMDB data to generate final dataframe
df_tmdb["omdb_id"] = df_tmdb["imdb_id"]
df_imdb = pd.merge(df_tmdb, df_omdb, on="omdb_id", how="left")
df_imdb.head()
# Out:
#        ID                         Title  Adult     Budget  \
# 0  475557                         Joker  False   55000000
# 1  420809  Maleficent: Mistress of Evil  False          0
# 2  420818                 The Lion King  False  260000000
# 3  290859         Terminator: Dark Fate  False  160000000
# 4  429617     Spider-Man: Far from Home  False  160000000
#
#                                        Genres Language  \
# 0              ['Crime', 'Thriller', 'Drama']       en
# 1          ['Fantasy', 'Adventure', 'Family']       en
# 2         ['Adventure', 'Animation', 'Drama']       en
# 3               ['Action', 'Science Fiction']       en
# 4  ['Action', 'Adventure', 'Science Fiction']       en
#
#                                   Production Company  Popularity     Revenue  \
# 0  ['DC Entertainment', 'Warner Bros. Pictures', ...     462.910   568509478
# 1                           ['Walt Disney Pictures']     287.919           0
# 2  ['Walt Disney Pictures', 'Fairview Entertainme...     183.255  1649676757
# 3  ['Lightstorm Entertainment', 'Skydance Media',...     153.313           0
# 4  ['Marvel Studios', 'Sony Pictures', 'Columbia ...     123.576  1131450163
#
#                       Production Country  ... omdb_released  omdb_runtime  \
# 0           ['United States of America']  ...   04 Oct 2019       122 min
# 1           ['United States of America']  ...   18 Oct 2019       118 min
# 2           ['United States of America']  ...   19 Jul 2019       118 min
# 3  ['China', 'United States of America']  ...   01 Nov 2019           NaN
# 4           ['United States of America']  ...   02 Jul 2019       129 min
#
#      omdb_director                                        omdb_actors  \
# 0    Todd Phillips  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...
# 1  Joachim Rønning  Angelina Jolie, Elle Fanning, Imelda Staunton,...
# 2      Jon Favreau  Chiwetel Ejiofor, John Oliver, James Earl Jone...
# 3       Tim Miller  Linda Hamilton, Arnold Schwarzenegger, Mackenz...
# 4        Jon Watts  Tom Holland, Samuel L. Jackson, Jake Gyllenhaa...
#
#              omdb_language omdb_country  \
# 0                  English  USA, Canada
# 1                  English          USA
# 2                  English          USA
# 3                  English   China, USA
# 4  Italian, Czech, English          USA
#
#                                         omdb_ratings omdb_metascore  \
# 0  [{'Source': 'Internet Movie Database', 'Value'...           59.0
# 1    [{'Source': 'Rotten Tomatoes', 'Value': '51%'}]            NaN
# 2  [{'Source': 'Internet Movie Database', 'Value'...           55.0
# 3                                                 []            NaN
# 4  [{'Source': 'Internet Movie Database', 'Value'...           69.0
#
#   omdb_imdbRating omdb_imdbVotes
# 0             8.9        360,218
# 1             NaN            NaN
# 2             7.1        102,621
# 3             NaN            NaN
# 4             7.7        187,214
#
# [5 rows x 29 columns]

# %%
df_imdb.to_csv("output_data/imdb_api_movie_2019.csv",index=False)

# %% [markdown]
# #### Clean Up Final Data Frame

# %%
#Get the column names to drop repeat columns
df_imdb.columns
# Out:
# Index(['ID', 'Title', 'Adult', 'Budget', 'Genres', 'Language',
#        'Production Company', 'Popularity', 'Revenue', 'Production Country',
#        'Release Date', 'Run Time', 'Vote Average', 'Vote Count', 'imdb_id',
#        'omdb_id', 'omdb_title', 'omdb_year', 'omdb_rated', 'omdb_released',
#        'omdb_runtime', 'omdb_director', 'omdb_actors', 'omdb_language',
#        'omdb_country', 'omdb_ratings', 'omdb_metascore', 'omdb_imdbRating',
#        'omdb_imdbVotes'],
#       dtype='object')

# %%
df_movie=df_imdb.drop(columns=["Release Date","omdb_released","Language","omdb_runtime","imdb_id","omdb_id","omdb_title","omdb_year","omdb_country","omdb_ratings"])
df_movie.head()
# Out:
#        ID                         Title  Adult     Budget  \
# 0  475557                         Joker  False   55000000
# 1  420809  Maleficent: Mistress of Evil  False          0
# 2  420818                 The Lion King  False  260000000
# 3  290859         Terminator: Dark Fate  False  160000000
# 4  429617     Spider-Man: Far from Home  False  160000000
#
#                                        Genres  \
# 0              ['Crime', 'Thriller', 'Drama']
# 1          ['Fantasy', 'Adventure', 'Family']
# 2         ['Adventure', 'Animation', 'Drama']
# 3               ['Action', 'Science Fiction']
# 4  ['Action', 'Adventure', 'Science Fiction']
#
#                                   Production Company  Popularity     Revenue  \
# 0  ['DC Entertainment', 'Warner Bros. Pictures', ...     462.910   568509478
# 1                           ['Walt Disney Pictures']     287.919           0
# 2  ['Walt Disney Pictures', 'Fairview Entertainme...     183.255  1649676757
# 3  ['Lightstorm Entertainment', 'Skydance Media',...     153.313           0
# 4  ['Marvel Studios', 'Sony Pictures', 'Columbia ...     123.576  1131450163
#
#                       Production Country  Run Time  Vote Average  Vote Count  \
# 0           ['United States of America']     122.0           8.6        3863
# 1           ['United States of America']     118.0           7.1         317
# 2           ['United States of America']     118.0           7.1        3132
# 3  ['China', 'United States of America']     128.0           7.4          29
# 4           ['United States of America']     129.0           7.6        4610
#
#   omdb_rated    omdb_director  \
# 0          R    Todd Phillips
# 1         PG  Joachim Rønning
# 2         PG      Jon Favreau
# 3        NaN       Tim Miller
# 4      PG-13        Jon Watts
#
#                                          omdb_actors            omdb_language  \
# 0  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...                  English
# 1  Angelina Jolie, Elle Fanning, Imelda Staunton,...                  English
# 2  Chiwetel Ejiofor, John Oliver, James Earl Jone...                  English
# 3  Linda Hamilton, Arnold Schwarzenegger, Mackenz...                  English
# 4  Tom Holland, Samuel L. Jackson, Jake Gyllenhaa...  Italian, Czech, English
#
#    omdb_metascore  omdb_imdbRating omdb_imdbVotes
# 0            59.0              8.9        360,218
# 1             NaN              NaN            NaN
# 2            55.0              7.1        102,621
# 3             NaN              NaN            NaN
# 4            69.0              7.7        187,214

# %%
#Convert 0 value in Budget and Revenue to NaN since 0 means missing data here
df_movie["Budget"] = df_movie["Budget"].replace(0,np.nan)
df_movie["Revenue"] = df_movie["Revenue"].replace(0,np.nan)
df_movie.head()
# Out:
#        ID                         Title  Adult       Budget  \
# 0  475557                         Joker  False   55000000.0
# 1  420809  Maleficent: Mistress of Evil  False          NaN
# 2  420818                 The Lion King  False  260000000.0
# 3  290859         Terminator: Dark Fate  False  160000000.0
# 4  429617     Spider-Man: Far from Home  False  160000000.0
#
#                                        Genres  \
# 0              ['Crime', 'Thriller', 'Drama']
# 1          ['Fantasy', 'Adventure', 'Family']
# 2         ['Adventure', 'Animation', 'Drama']
# 3               ['Action', 'Science Fiction']
# 4  ['Action', 'Adventure', 'Science Fiction']
#
#                                   Production Company  Popularity  \
# 0  ['DC Entertainment', 'Warner Bros. Pictures', ...     462.910
# 1                           ['Walt Disney Pictures']     287.919
# 2  ['Walt Disney Pictures', 'Fairview Entertainme...     183.255
# 3  ['Lightstorm Entertainment', 'Skydance Media',...     153.313
# 4  ['Marvel Studios', 'Sony Pictures', 'Columbia ...     123.576
#
#         Revenue                     Production Country  Run Time  \
# 0  5.685095e+08           ['United States of America']     122.0
# 1           NaN           ['United States of America']     118.0
# 2  1.649677e+09           ['United States of America']     118.0
# 3           NaN  ['China', 'United States of America']     128.0
# 4  1.131450e+09           ['United States of America']     129.0
#
#    Vote Average  Vote Count omdb_rated    omdb_director  \
# 0           8.6        3863          R    Todd Phillips
# 1           7.1         317         PG  Joachim Rønning
# 2           7.1        3132         PG      Jon Favreau
# 3           7.4          29        NaN       Tim Miller
# 4           7.6        4610      PG-13        Jon Watts
#
#                                          omdb_actors            omdb_language  \
# 0  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...                  English
# 1  Angelina Jolie, Elle Fanning, Imelda Staunton,...                  English
# 2  Chiwetel Ejiofor, John Oliver, James Earl Jone...                  English
# 3  Linda Hamilton, Arnold Schwarzenegger, Mackenz...                  English
# 4  Tom Holland, Samuel L. Jackson, Jake Gyllenhaa...  Italian, Czech, English
#
#    omdb_metascore  omdb_imdbRating omdb_imdbVotes
# 0            59.0              8.9        360,218
# 1             NaN              NaN            NaN
# 2            55.0              7.1        102,621
# 3             NaN              NaN            NaN
# 4            69.0              7.7        187,214

# %% [markdown]
# #### Cleaning Result Summary

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
# ID                    9994 non-null int64
# Title                 9994 non-null object
# Adult                 9994 non-null bool
# Budget                3233 non-null float64
# Genres                9994 non-null object
# Production Company    9994 non-null object
# Popularity            9994 non-null float64
# Revenue               2938 non-null float64
# Production Country    9994 non-null object
# Run Time              9646 non-null float64
# Vote Average          9994 non-null float64
# Vote Count            9994 non-null int64
# omdb_rated            7502 non-null object
# omdb_director         9704 non-null object
# omdb_actors           9698 non-null object
# omdb_language         9613 non-null object
# omdb_metascore        4568 non-null float64
# omdb_imdbRating       9579 non-null float64
# omdb_imdbVotes        9579 non-null object
# dtypes: bool(1), float64(7), int64(2), object(9)
# memory usage: 1.5+ MB

# %%
df_movie.to_csv("output_data/cleanup_movie_2019.csv",index=False)
